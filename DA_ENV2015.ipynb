# %%
#import os
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
#cwd = os.getcwd()

# %%
df=pd.read_csv("C:/Users/bazra/Desktop/Projet RED/BASE_ENV_2015/ENV2015_Santé_Consult.csv", encoding="cp1252", low_memory=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47635 entries, 0 to 47634
# Columns: 534 entries, hh1 to diplome
# dtypes: float64(210), int64(40), object(284)
# memory usage: 194.1+ MB

# %%
df.head()
# Out:
#    hh1  hh2 finterview  a01  a02 finterview2       a03  a03jj a03mm  a03aa  \
# 0    1    1          T    7    3           T  14032015     14  mars  annee
# 1    1    1          T    7    3           T  14032015     14  mars  annee
# 2    1    2          T    7    3           T  14032015     14  mars  annee
# 3    1    2          T    7    3           T  14032015     14  mars  annee
# 4    1    2          T    7    3           T  14032015     14  mars  annee
#
#    ...   eo  nini  niniemp  nini2   agegroup  agegroup2  V02   v02new  \
# 0  ...  0.0   NaN      NaN    NaN    Age 36+  Age 36-59    1  Abidjan
# 1  ...  0.0   NaN      NaN    NaN    Age 36+  Age 36-59    1  Abidjan
# 2  ...  NaN   1.0      1.0    0.0  Age 14-35  Age 14-24    1  Abidjan
# 3  ...  NaN   1.0      1.0    1.0  Age 14-35  Age 14-24    1  Abidjan
# 4  ...  NaN   NaN      NaN    NaN        NaN        NaN    1  Abidjan
#
#     education         diplome
# 0       aucun               0
# 1       aucun               0
# ...

# %%
# Selection of specific columns
colonnes = ["cq1a", "cq2c"]
print(df[colonnes])
# Out:
#       cq1a cq2c
# 0      non  NaN
# 1      non  NaN
# 2      non  NaN
# 3      non  NaN
# 4      non  NaN
# ...    ...  ...
# 47630  non  NaN
# 47631  non  NaN
# 47632  non  NaN
# 47633  non  NaN
# 47634  non  NaN
#
# [47635 rows x 2 columns]

# %%
#Making a histogram of cq1a (Consultation) variable
plt.figure(figsize=(3,3))
plt.hist(df['cq1a'])
plt.show()

# %%
#Making a histogram of a1(gender)variable
plt.figure(figsize=(3,3))
plt.hist(df['a1'])
plt.show()

# %%
df['a1'].value_counts()
# Out:
# a1
# masculin    24023
# féminin     23612
# Name: count, dtype: int64
